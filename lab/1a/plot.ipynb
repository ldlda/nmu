# %% [markdown]
# # urgh
#
# import

# %%
import numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# get to work
#
# ## linspace, function.
#
# linspace is just linear spaces that is dense enough so it looks pleasant

# %%
x = np.linspace(-5, 5, 20)  # they use arange more so look into that

y = x + 1
y2 = -x + 2

# %% [markdown]
# ## plot
#
# im discovering all of this as i type. deadass never used plot in my life

# %%
# %matplotlib inline

plt.plot(x, y)

plt.plot(x, y2)

plt.title("cant be arsed")
# Out:
# Text(0.5, 1.0, 'cant be arsed')

# %% [markdown]
# ## hmm
#
# why
